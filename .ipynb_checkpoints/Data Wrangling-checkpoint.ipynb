# %% [markdown]
# ### 1. Read in the dataset personality_scores.csv in this repo. Examine the data frame for duplicates (based on ID), and drop any duplicates that exist. Assert that the new data frame is the length of the unique entries of the original data frame.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
personality_data = pd.read_csv('CSV/personality_scores.csv',delimiter=';')
personality_data = personality_data.drop_duplicates(subset='ID')
personality_data =personality_data.set_index('ID')
personality_data = personality_data.dropna(axis=1)
#print(personality_data.isna())
display(personality_data.head())
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
# 3                                (5, 5)
# 4                                (5, 3)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 3)
#
#    Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                              (5, 3)
# 1                                              (5, 3)
# 2                                              (5, 5)
# 3                                              (5, 3)
# 4                                              (5, 3)
#
#    Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                              (2, 3)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 5)
#
#    Section 5 of 6 [I am quiet around strangers.]  ...  \
# ID                                                ...
# 0                                         (1, 3)  ...
# 1                                         (1, 3)  ...
# 2                                         (1, 1)  ...
# 3                                         (1, 3)  ...
# 4                                         (1, 1)  ...
#
#    Section 5 of 6 [I often forget to put things back in their proper place]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 5)
# 3                                              (3, 1)
# 4                                              (3, 5)
#
#    Section 5 of 6 [I pay attention to details.]  \
# ID
# 0                                        (3, 5)
# 1                                        (3, 1)
# 2                                        (3, 5)
# 3                                        (3, 5)
# 4                                        (3, 5)
#
#    Section 5 of 6 [I seldom feel blue (down).]  \
# ID
# 0                                       (4, 3)
# 1                                       (4, 1)
# 2                                       (4, 1)
# 3                                       (4, 1)
# 4                                       (4, 5)
#
#    Section 5 of 6 [I spend time reflecting on things.]  \
# ID
# 0                                              (5, 5)
# 1                                              (5, 5)
# 2                                              (5, 3)
# 3                                              (5, 5)
# 4                                              (5, 5)
#
#    Section 5 of 6 [I start conversations.]  \
# ID
# 0                                   (1, 3)
# 1                                   (1, 5)
# 2                                   (1, 3)
# 3                                   (1, 5)
# 4                                   (1, 3)
#
#    Section 5 of 6 [I sympathize with others' feelings.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 5)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I take time out for others.]  \
# ID
# 0                                        (2, 5)
# 1                                        (2, 5)
# 2                                        (2, 5)
# 3                                        (2, 5)
# 4                                        (2, 5)
#
#    Section 5 of 6 [I talk to a lot of different people at parties.]  \
# ID
# 0                                              (1, 3)
# 1                                              (1, 5)
# 2                                              (1, 3)
# 3                                              (1, 5)
# 4                                              (1, 3)
#
#    Section 5 of 6 [I use difficult words.]  \
# ID
# 0                                   (5, 1)
# 1                                   (5, 3)
# 2                                   (5, 1)
# 3                                   (5, 1)
# 4                                   (5, 1)
#
#    Section 5 of 6 [I worry about things.]
# ID
# 0                                  (4, 3)
# 1                                  (4, 3)
# 2                                  (4, 3)
# 3                                  (4, 1)
# 4                                  (4, 3)
#
# [5 rows x 50 columns]

# %% [markdown]
# ### 2.Write functions that will (1) convert the answer on each of the personality test questions to a number, as set out in scoring, and (2) calculate total scores for each of the subscales (conscientiousness, emotional stability, openness to new experience, agreeableness, extraversion). As you are doing this, first create unit tests that will test that the functions work as they should.

# %%
def assigning(row,Category_Num):
    count = 0
    asd = 0
    for column in personality_data.columns:
        tuplee = row[column]
        if type(tuplee) == str:
            catergory = tuplee[1]
            result = int(tuplee[4])
            if catergory == Category_Num:
                count += result
    return count

# %%
personality_data['Extraversion'] = personality_data.apply(lambda row : assigning(row,'1'), axis = 1)
personality_data['Agreeableness'] = personality_data.apply(lambda row : assigning(row,'2'), axis = 1)
personality_data['Conscientiousness'] = personality_data.apply(lambda row : assigning(row,'3'), axis = 1)
personality_data['Emotional Stability'] = personality_data.apply(lambda row : assigning(row,'4'), axis = 1)
personality_data['Openness to experiences'] = personality_data.apply(lambda row : assigning(row,'5'), axis = 1)

# %%
personality_data.head()
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
# 3                                (5, 5)
# 4                                (5, 3)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 3)
#
#    Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                              (5, 3)
# 1                                              (5, 3)
# 2                                              (5, 5)
# 3                                              (5, 3)
# 4                                              (5, 3)
#
#    Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                              (2, 3)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 5)
#
#    Section 5 of 6 [I am quiet around strangers.]  ...  \
# ID                                                ...
# 0                                         (1, 3)  ...
# 1                                         (1, 3)  ...
# 2                                         (1, 1)  ...
# 3                                         (1, 3)  ...
# 4                                         (1, 1)  ...
#
#    Section 5 of 6 [I sympathize with others' feelings.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 5)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I take time out for others.]  \
# ID
# 0                                        (2, 5)
# 1                                        (2, 5)
# 2                                        (2, 5)
# 3                                        (2, 5)
# 4                                        (2, 5)
#
#    Section 5 of 6 [I talk to a lot of different people at parties.]  \
# ID
# 0                                              (1, 3)
# 1                                              (1, 5)
# 2                                              (1, 3)
# 3                                              (1, 5)
# 4                                              (1, 3)
#
#    Section 5 of 6 [I use difficult words.]  \
# ID
# 0                                   (5, 1)
# 1                                   (5, 3)
# 2                                   (5, 1)
# 3                                   (5, 1)
# 4                                   (5, 1)
#
#    Section 5 of 6 [I worry about things.] Extraversion Agreeableness  \
# ID
# 0                                  (4, 3)           30            40
# 1                                  (4, 3)           42            46
# 2                                  (4, 3)           28            40
# 3                                  (4, 1)           30            38
# 4                                  (4, 3)           28            34
#
#    Conscientiousness Emotional Stability Openness to experiences
# ID
# 0                 48                  36                      42
# 1                 46                  40                      42
# 2                 40                  38                      42
# 3                 38                  40                      38
# 4                 46                  38                      36
#
# [5 rows x 55 columns]

# %% [markdown]
# ### 1 . Create a function/functions that takes in subscale total, and for each subscale, creates a new column called “{subscale_name}_interpretation” (e.g., conscientiousness_interpretation) and applies the labels “low”, “medium”, or “high” according to a person’s score on that subscale. Cut-off scores corresponding to the low, medium and high groups can be found in scoring.md. Again, write a unit test before creating this function that tests whether the generate_score_interpretation function works.

# %%
def subscale(score,name):
    mean = personality_data[name].mean()
    std = personality_data[name].std()
    high = (mean + std)/2
    low = (mean - std)/2
    
    if score >= high:
        return 'high'
    elif score <= low:
        return 'low'
    else:
        return 'medium'

# %%
personality_data['Extraversion_Interpretation'] = personality_data['Extraversion'].apply(lambda column: subscale(column,'Emotional Stability'))
personality_data['Agreeableness_Interpretation'] = personality_data['Agreeableness'].apply(lambda column: subscale(column,'Agreeableness'))
personality_data['Conscientiousness_Interpretation'] = personality_data['Conscientiousness'].apply(lambda column: subscale(column,'Conscientiousness'))
personality_data['Emotional_Stability_Interpretation'] = personality_data['Emotional Stability'].apply(lambda column: subscale(column,'Emotional Stability'))
personality_data['Openness_to_experiences_Interpretation'] = personality_data['Openness to experiences'].apply(lambda column: subscale(column,'Openness to experiences'))

# %%
display(personality_data.head())
personality_data['Agreeableness_Interpretation'].value_counts()
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
# 3                                (5, 5)
# 4                                (5, 3)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 3)
#
#    Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                              (5, 3)
# 1                                              (5, 3)
# 2                                              (5, 5)
# 3                                              (5, 3)
# 4                                              (5, 3)
#
#    Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                              (2, 3)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 5)
#
#    Section 5 of 6 [I am quiet around strangers.]  ... Extraversion  \
# ID                                                ...
# 0                                         (1, 3)  ...           30
# 1                                         (1, 3)  ...           42
# 2                                         (1, 1)  ...           28
# 3                                         (1, 3)  ...           30
# 4                                         (1, 1)  ...           28
#
#    Agreeableness Conscientiousness Emotional Stability  \
# ID
# 0             40                48                  36
# 1             46                46                  40
# 2             40                40                  38
# 3             38                38                  40
# 4             34                46                  38
#
#    Openness to experiences Extraversion_Interpretation  \
# ID
# 0                       42                        high
# 1                       42                        high
# 2                       42                        high
# 3                       38                        high
# 4                       36                        high
#
#    Agreeableness_Interpretation Conscientiousness_Interpretation  \
# ID
# 0                          high                             high
# 1                          high                             high
# 2                          high                             high
# 3                          high                             high
# 4                          high                             high
#
#    Emotional_Stability_Interpretation Openness_to_experiences_Interpretation
# ID
# 0                                high                                   high
# 1                                high                                   high
# 2                                high                                   high
# 3                                high                                   high
# 4                                high                                   high
#
# [5 rows x 60 columns]
# high      1553
# medium       2
# Name: Agreeableness_Interpretation, dtype: int64

# %% [markdown]
# ### 2 . Read in the data in departments.csv and merge this data frame with the personality score data frame, keeping all applicants within the department data frame. Assert that the newly created merged data frame has the same amount of rows as the department data frame, and the expected number of columns.

# %%
departments_data = pd.read_csv('CSV/departments.csv',delimiter=';')

# %%
#departments_data = departments_data.drop_duplicates(subset='ID')
#departments_data =departments_data.set_index('ID')
departments_data = departments_data.dropna(axis=1)
departments_data.head()

combined_data = pd.merge(left=personality_data, right=departments_data, left_on='ID', right_on='ID')
combined_data =combined_data.set_index('ID')
display(combined_data)
# Out:
#      Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                    (3, 5)
# 1                                    (3, 5)
# 2                                    (3, 5)
# 3                                    (3, 5)
# 4                                    (3, 3)
# 5                                    (3, 5)
# 6                                    (3, 5)
# 7                                    (3, 5)
# 8                                    (3, 5)
# 9                                    (3, 3)
# 10                                   (3, 5)
# 11                                   (3, 5)
# 12                                   (3, 5)
# 13                                   (3, 3)
# 14                                   (3, 5)
# 15                                   (3, 5)
# 16                                   (3, 5)
# 17                                   (3, 5)
# 18                                   (3, 5)
# 19                                   (3, 3)
# 20                                   (3, 5)
# 21                                   (3, 5)
# 22                                   (3, 5)
# 23                                   (3, 3)
# 24                                   (3, 3)
# 25                                   (3, 5)
# 26                                   (3, 5)
# 27                                   (3, 5)
# 28                                   (3, 3)
# 29                                   (3, 5)
# ...                                     ...
# 1525                                 (3, 5)
# 1526                                 (3, 3)
# 1527                                 (3, 5)
# 1528                                 (3, 3)
# 1529                                 (3, 5)
# 1530                                 (3, 5)
# 1531                                 (3, 3)
# 1532                                 (3, 5)
# 1533                                 (3, 5)
# 1534                                 (3, 5)
# 1535                                 (3, 3)
# 1536                                 (3, 5)
# 1537                                 (3, 3)
# 1538                                 (3, 5)
# 1539                                 (3, 5)
# 1540                                 (3, 1)
# 1541                                 (3, 5)
# 1542                                 (3, 5)
# 1543                                 (3, 5)
# 1544                                 (3, 3)
# 1545                                 (3, 5)
# 1546                                 (3, 5)
# 1547                                 (3, 5)
# 1548                                 (3, 3)
# 1549                                 (3, 3)
# 1550                                 (3, 5)
# 1551                                 (3, 3)
# 1552                                 (3, 5)
# 1553                                 (3, 5)
# 1554                                 (3, 3)
#
#      Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                     (4, 5)
# 1                                     (4, 5)
# 2                                     (4, 3)
# 3                                     (4, 5)
# 4                                     (4, 5)
# 5                                     (4, 5)
# 6                                     (4, 5)
# 7                                     (4, 5)
# 8                                     (4, 5)
# 9                                     (4, 3)
# 10                                    (4, 5)
# 11                                    (4, 5)
# 12                                    (4, 3)
# 13                                    (4, 3)
# 14                                    (4, 5)
# 15                                    (4, 5)
# 16                                    (4, 3)
# 17                                    (4, 5)
# 18                                    (4, 1)
# 19                                    (4, 1)
# 20                                    (4, 3)
# 21                                    (4, 3)
# 22                                    (4, 3)
# 23                                    (4, 5)
# 24                                    (4, 5)
# 25                                    (4, 3)
# 26                                    (4, 5)
# 27                                    (4, 3)
# 28                                    (4, 5)
# 29                                    (4, 5)
# ...                                      ...
# 1525                                  (4, 5)
# 1526                                  (4, 5)
# 1527                                  (4, 5)
# 1528                                  (4, 3)
# 1529                                  (4, 3)
# 1530                                  (4, 5)
# 1531                                  (4, 3)
# 1532                                  (4, 5)
# 1533                                  (4, 5)
# 1534                                  (4, 5)
# 1535                                  (4, 5)
# 1536                                  (4, 5)
# 1537                                  (4, 5)
# 1538                                  (4, 5)
# 1539                                  (4, 3)
# 1540                                  (4, 3)
# 1541                                  (4, 3)
# 1542                                  (4, 5)
# 1543                                  (4, 5)
# 1544                                  (4, 1)
# 1545                                  (4, 3)
# 1546                                  (4, 3)
# 1547                                  (4, 5)
# 1548                                  (4, 3)
# 1549                                  (4, 1)
# 1550                                  (4, 5)
# 1551                                  (4, 5)
# 1552                                  (4, 3)
# 1553                                  (4, 5)
# 1554                                  (4, 5)
#
#      Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                                (3, 5)
# 1                                                (3, 5)
# 2                                                (3, 3)
# 3                                                (3, 3)
# 4                                                (3, 3)
# 5                                                (3, 3)
# 6                                                (3, 5)
# 7                                                (3, 3)
# 8                                                (3, 5)
# 9                                                (3, 3)
# 10                                               (3, 1)
# 11                                               (3, 5)
# 12                                               (3, 3)
# 13                                               (3, 5)
# 14                                               (3, 3)
# 15                                               (3, 1)
# 16                                               (3, 3)
# 17                                               (3, 3)
# 18                                               (3, 5)
# 19                                               (3, 5)
# 20                                               (3, 5)
# 21                                               (3, 1)
# 22                                               (3, 5)
# 23                                               (3, 3)
# 24                                               (3, 1)
# 25                                               (3, 1)
# 26                                               (3, 5)
# 27                                               (3, 5)
# 28                                               (3, 5)
# 29                                               (3, 5)
# ...                                                 ...
# 1525                                             (3, 5)
# 1526                                             (3, 1)
# 1527                                             (3, 5)
# 1528                                             (3, 3)
# 1529                                             (3, 3)
# 1530                                             (3, 5)
# 1531                                             (3, 3)
# 1532                                             (3, 3)
# 1533                                             (3, 1)
# 1534                                             (3, 1)
# 1535                                             (3, 5)
# 1536                                             (3, 5)
# 1537                                             (3, 3)
# 1538                                             (3, 5)
# 1539                                             (3, 1)
# 1540                                             (3, 3)
# 1541                                             (3, 5)
# 1542                                             (3, 1)
# 1543                                             (3, 1)
# 1544                                             (3, 3)
# 1545                                             (3, 3)
# 1546                                             (3, 5)
# 1547                                             (3, 1)
# 1548                                             (3, 5)
# 1549                                             (3, 3)
# 1550                                             (3, 1)
# 1551                                             (3, 5)
# 1552                                             (3, 5)
# 1553                                             (3, 5)
# 1554                                             (3, 1)
#
#      Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                  (5, 5)
# 1                                  (5, 5)
# 2                                  (5, 5)
# 3                                  (5, 5)
# 4                                  (5, 3)
# 5                                  (5, 5)
# 6                                  (5, 5)
# 7                                  (5, 5)
# 8                                  (5, 5)
# 9                                  (5, 5)
# 10                                 (5, 5)
# 11                                 (5, 5)
# 12                                 (5, 3)
# 13                                 (5, 5)
# 14                                 (5, 5)
# 15                                 (5, 5)
# 16                                 (5, 1)
# 17                                 (5, 3)
# 18                                 (5, 5)
# 19                                 (5, 5)
# 20                                 (5, 5)
# 21                                 (5, 5)
# 22                                 (5, 5)
# 23                                 (5, 5)
# 24                                 (5, 3)
# 25                                 (5, 5)
# 26                                 (5, 5)
# 27                                 (5, 5)
# 28                                 (5, 5)
# 29                                 (5, 5)
# ...                                   ...
# 1525                               (5, 5)
# 1526                               (5, 3)
# 1527                               (5, 3)
# 1528                               (5, 5)
# 1529                               (5, 3)
# 1530                               (5, 3)
# 1531                               (5, 5)
# 1532                               (5, 5)
# 1533                               (5, 1)
# 1534                               (5, 5)
# 1535                               (5, 3)
# 1536                               (5, 5)
# 1537                               (5, 3)
# 1538                               (5, 3)
# 1539                               (5, 5)
# 1540                               (5, 5)
# 1541                               (5, 5)
# 1542                               (5, 5)
# 1543                               (5, 5)
# 1544                               (5, 3)
# 1545                               (5, 5)
# 1546                               (5, 5)
# 1547                               (5, 5)
# 1548                               (5, 5)
# 1549                               (5, 5)
# 1550                               (5, 5)
# 1551                               (5, 3)
# 1552                               (5, 5)
# 1553                               (5, 5)
# 1554                               (5, 5)
#
#      Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                         (2, 3)
# 1                                         (2, 5)
# 2                                         (2, 5)
# 3                                         (2, 5)
# 4                                         (2, 3)
# 5                                         (2, 5)
# 6                                         (2, 5)
# 7                                         (2, 5)
# 8                                         (2, 5)
# 9                                         (2, 5)
# 10                                        (2, 5)
# 11                                        (2, 3)
# 12                                        (2, 5)
# 13                                        (2, 5)
# 14                                        (2, 3)
# 15                                        (2, 5)
# 16                                        (2, 5)
# 17                                        (2, 5)
# 18                                        (2, 5)
# 19                                        (2, 3)
# 20                                        (2, 5)
# 21                                        (2, 3)
# 22                                        (2, 5)
# 23                                        (2, 3)
# 24                                        (2, 5)
# 25                                        (2, 5)
# 26                                        (2, 5)
# 27                                        (2, 5)
# 28                                        (2, 5)
# 29                                        (2, 5)
# ...                                          ...
# 1525                                      (2, 5)
# 1526                                      (2, 3)
# 1527                                      (2, 5)
# 1528                                      (2, 5)
# 1529                                      (2, 5)
# 1530                                      (2, 5)
# 1531                                      (2, 3)
# 1532                                      (2, 5)
# 1533                                      (2, 5)
# 1534                                      (2, 5)
# 1535                                      (2, 5)
# 1536                                      (2, 5)
# 1537                                      (2, 5)
# 1538                                      (2, 5)
# 1539                                      (2, 5)
# 1540                                      (2, 5)
# 1541                                      (2, 5)
# 1542                                      (2, 5)
# 1543                                      (2, 5)
# 1544                                      (2, 5)
# 1545                                      (2, 3)
# 1546                                      (2, 5)
# 1547                                      (2, 5)
# 1548                                      (2, 5)
# 1549                                      (2, 5)
# 1550                                      (2, 5)
# 1551                                      (2, 5)
# 1552                                      (2, 5)
# 1553                                      (2, 5)
# 1554                                      (2, 5)
#
#      Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                                (5, 3)
# 1                                                (5, 3)
# 2                                                (5, 5)
# 3                                                (5, 3)
# 4                                                (5, 3)
# 5                                                (5, 3)
# 6                                                (5, 3)
# 7                                                (5, 5)
# 8                                                (5, 5)
# 9                                                (5, 3)
# 10                                               (5, 5)
# 11                                               (5, 5)
# 12                                               (5, 5)
# 13                                               (5, 5)
# 14                                               (5, 3)
# 15                                               (5, 3)
# 16                                               (5, 5)
# 17                                               (5, 5)
# 18                                               (5, 5)
# 19                                               (5, 5)
# 20                                               (5, 5)
# 21                                               (5, 5)
# 22                                               (5, 5)
# 23                                               (5, 5)
# 24                                               (5, 5)
# 25                                               (5, 3)
# 26                                               (5, 5)
# 27                                               (5, 5)
# 28                                               (5, 1)
# 29                                               (5, 1)
# ...                                                 ...
# 1525                                             (5, 5)
# 1526                                             (5, 3)
# 1527                                             (5, 5)
# 1528                                             (5, 5)
# 1529                                             (5, 3)
# 1530                                             (5, 3)
# 1531                                             (5, 3)
# 1532                                             (5, 5)
# 1533                                             (5, 1)
# 1534                                             (5, 5)
# 1535                                             (5, 5)
# 1536                                             (5, 5)
# 1537                                             (5, 5)
# 1538                                             (5, 5)
# 1539                                             (5, 3)
# 1540                                             (5, 5)
# 1541                                             (5, 3)
# 1542                                             (5, 3)
# 1543                                             (5, 3)
# 1544                                             (5, 3)
# 1545                                             (5, 5)
# 1546                                             (5, 3)
# 1547                                             (5, 5)
# 1548                                             (5, 5)
# 1549                                             (5, 3)
# 1550                                             (5, 5)
# 1551                                             (5, 3)
# 1552                                             (5, 5)
# 1553                                             (5, 5)
# 1554                                             (5, 3)
#
#      Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                                (2, 3)
# 1                                                (2, 5)
# 2                                                (2, 5)
# 3                                                (2, 3)
# 4                                                (2, 3)
# 5                                                (2, 5)
# 6                                                (2, 5)
# 7                                                (2, 5)
# 8                                                (2, 5)
# 9                                                (2, 5)
# 10                                               (2, 5)
# 11                                               (2, 3)
# 12                                               (2, 5)
# 13                                               (2, 3)
# 14                                               (2, 3)
# 15                                               (2, 1)
# 16                                               (2, 5)
# 17                                               (2, 3)
# 18                                               (2, 3)
# 19                                               (2, 5)
# 20                                               (2, 5)
# 21                                               (2, 5)
# 22                                               (2, 5)
# 23                                               (2, 5)
# 24                                               (2, 5)
# 25                                               (2, 3)
# 26                                               (2, 5)
# 27                                               (2, 5)
# 28                                               (2, 5)
# 29                                               (2, 5)
# ...                                                 ...
# 1525                                             (2, 5)
# 1526                                             (2, 5)
# 1527                                             (2, 5)
# 1528                                             (2, 5)
# 1529                                             (2, 5)
# 1530                                             (2, 5)
# 1531                                             (2, 5)
# 1532                                             (2, 5)
# 1533                                             (2, 5)
# 1534                                             (2, 5)
# 1535                                             (2, 5)
# 1536                                             (2, 5)
# 1537                                             (2, 5)
# 1538                                             (2, 5)
# 1539                                             (2, 5)
# 1540                                             (2, 5)
# 1541                                             (2, 3)
# 1542                                             (2, 3)
# 1543                                             (2, 3)
# 1544                                             (2, 3)
# 1545                                             (2, 3)
# 1546                                             (2, 3)
# 1547                                             (2, 1)
# 1548                                             (2, 3)
# 1549                                             (2, 3)
# 1550                                             (2, 5)
# 1551                                             (2, 3)
# 1552                                             (2, 3)
# 1553                                             (2, 5)
# 1554                                             (2, 3)
#
#      Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                                (2, 5)
# 1                                                (2, 5)
# 2                                                (2, 5)
# 3                                                (2, 3)
# 4                                                (2, 3)
# 5                                                (2, 5)
# 6                                                (2, 5)
# 7                                                (2, 5)
# 8                                                (2, 5)
# 9                                                (2, 3)
# 10                                               (2, 5)
# 11                                               (2, 3)
# 12                                               (2, 5)
# 13                                               (2, 5)
# 14                                               (2, 3)
# 15                                               (2, 3)
# 16                                               (2, 5)
# 17                                               (2, 5)
# 18                                               (2, 3)
# 19                                               (2, 3)
# 20                                               (2, 5)
# 21                                               (2, 5)
# 22                                               (2, 5)
# 23                                               (2, 5)
# 24                                               (2, 5)
# 25                                               (2, 1)
# 26                                               (2, 5)
# 27                                               (2, 5)
# 28                                               (2, 1)
# 29                                               (2, 5)
# ...                                                 ...
# 1525                                             (2, 5)
# 1526                                             (2, 3)
# 1527                                             (2, 5)
# 1528                                             (2, 5)
# 1529                                             (2, 3)
# 1530                                             (2, 5)
# 1531                                             (2, 3)
# 1532                                             (2, 5)
# 1533                                             (2, 5)
# 1534                                             (2, 5)
# 1535                                             (2, 3)
# 1536                                             (2, 5)
# 1537                                             (2, 5)
# 1538                                             (2, 5)
# 1539                                             (2, 5)
# 1540                                             (2, 5)
# 1541                                             (2, 5)
# 1542                                             (2, 5)
# 1543                                             (2, 5)
# 1544                                             (2, 5)
# 1545                                             (2, 3)
# 1546                                             (2, 5)
# 1547                                             (2, 5)
# 1548                                             (2, 5)
# 1549                                             (2, 5)
# 1550                                             (2, 5)
# 1551                                             (2, 5)
# 1552                                             (2, 3)
# 1553                                             (2, 5)
# 1554                                             (2, 5)
#
#      Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                               (5, 5)
# 1                                               (5, 5)
# 2                                               (5, 5)
# 3                                               (5, 3)
# 4                                               (5, 5)
# 5                                               (5, 5)
# 6                                               (5, 5)
# 7                                               (5, 5)
# 8                                               (5, 5)
# 9                                               (5, 5)
# 10                                              (5, 5)
# 11                                              (5, 5)
# 12                                              (5, 5)
# 13                                              (5, 5)
# 14                                              (5, 3)
# 15                                              (5, 5)
# 16                                              (5, 5)
# 17                                              (5, 1)
# 18                                              (5, 5)
# 19                                              (5, 5)
# 20                                              (5, 5)
# 21                                              (5, 3)
# 22                                              (5, 5)
# 23                                              (5, 5)
# 24                                              (5, 5)
# 25                                              (5, 5)
# 26                                              (5, 5)
# 27                                              (5, 5)
# 28                                              (5, 3)
# 29                                              (5, 5)
# ...                                                ...
# 1525                                            (5, 5)
# 1526                                            (5, 5)
# 1527                                            (5, 3)
# 1528                                            (5, 5)
# 1529                                            (5, 5)
# 1530                                            (5, 3)
# 1531                                            (5, 5)
# 1532                                            (5, 5)
# 1533                                            (5, 5)
# 1534                                            (5, 5)
# 1535                                            (5, 5)
# 1536                                            (5, 5)
# 1537                                            (5, 5)
# 1538                                            (5, 5)
# 1539                                            (5, 5)
# 1540                                            (5, 5)
# 1541                                            (5, 5)
# 1542                                            (5, 5)
# 1543                                            (5, 5)
# 1544                                            (5, 3)
# 1545                                            (5, 3)
# 1546                                            (5, 3)
# 1547                                            (5, 5)
# 1548                                            (5, 3)
# 1549                                            (5, 5)
# 1550                                            (5, 5)
# 1551                                            (5, 5)
# 1552                                            (5, 5)
# 1553                                            (5, 5)
# 1554                                            (5, 3)
#
#      Section 5 of 6 [I am quiet around strangers.]  ... Agreeableness  \
# ID                                                  ...
# 0                                           (1, 3)  ...            40
# 1                                           (1, 3)  ...            46
# 2                                           (1, 1)  ...            40
# 3                                           (1, 3)  ...            38
# 4                                           (1, 1)  ...            34
# 5                                           (1, 5)  ...            46
# 6                                           (1, 3)  ...            44
# 7                                           (1, 5)  ...            48
# 8                                           (1, 5)  ...            46
# 9                                           (1, 1)  ...            44
# 10                                          (1, 3)  ...            44
# 11                                          (1, 3)  ...            36
# 12                                          (1, 5)  ...            46
# 13                                          (1, 3)  ...            40
# 14                                          (1, 1)  ...            40
# 15                                          (1, 5)  ...            38
# 16                                          (1, 3)  ...            46
# 17                                          (1, 5)  ...            36
# 18                                          (1, 1)  ...            40
# 19                                          (1, 1)  ...            40
# 20                                          (1, 1)  ...            50
# 21                                          (1, 5)  ...            32
# 22                                          (1, 1)  ...            46
# 23                                          (1, 3)  ...            46
# 24                                          (1, 1)  ...            46
# 25                                          (1, 3)  ...            26
# 26                                          (1, 1)  ...            46
# 27                                          (1, 1)  ...            48
# 28                                          (1, 3)  ...            40
# 29                                          (1, 3)  ...            44
# ...                                            ...  ...           ...
# 1525                                        (1, 3)  ...            42
# 1526                                        (1, 5)  ...            40
# 1527                                        (1, 3)  ...            50
# 1528                                        (1, 3)  ...            46
# 1529                                        (1, 3)  ...            46
# 1530                                        (1, 1)  ...            50
# 1531                                        (1, 1)  ...            44
# 1532                                        (1, 5)  ...            48
# 1533                                        (1, 3)  ...            44
# 1534                                        (1, 3)  ...            48
# 1535                                        (1, 5)  ...            40
# 1536                                        (1, 3)  ...            44
# 1537                                        (1, 5)  ...            42
# 1538                                        (1, 3)  ...            50
# 1539                                        (1, 3)  ...            48
# 1540                                        (1, 3)  ...            44
# 1541                                        (1, 3)  ...            40
# 1542                                        (1, 1)  ...            44
# 1543                                        (1, 1)  ...            44
# 1544                                        (1, 3)  ...            38
# 1545                                        (1, 1)  ...            32
# 1546                                        (1, 3)  ...            40
# 1547                                        (1, 1)  ...            42
# 1548                                        (1, 3)  ...            46
# 1549                                        (1, 1)  ...            44
# 1550                                        (1, 3)  ...            48
# 1551                                        (1, 5)  ...            48
# 1552                                        (1, 3)  ...            44
# 1553                                        (1, 5)  ...            38
# 1554                                        (1, 3)  ...            44
#
#      Conscientiousness Emotional Stability Openness to experiences  \
# ID
# 0                   48                  36                      42
# 1                   46                  40                      42
# 2                   40                  38                      42
# 3                   38                  40                      38
# 4                   46                  38                      36
# 5                   42                  46                      36
# 6                   50                  36                      42
# 7                   48                  42                      42
# 8                   48                  44                      48
# 9                   36                  18                      42
# 10                  46                  38                      40
# 11                  48                  20                      46
# 12                  36                  20                      38
# 13                  44                  42                      42
# 14                  42                  18                      36
# 15                  46                  34                      38
# 16                  48                  34                      42
# 17                  44                  42                      32
# 18                  36                  14                      44
# 19                  42                  24                      44
# 20                  50                  42                      36
# 21                  38                  40                      42
# 22                  50                  30                      48
# 23                  46                  38                      40
# 24                  38                  42                      36
# 25                  42                  34                      34
# 26                  40                  42                      48
# 27                  32                  14                      48
# 28                  38                  38                      30
# 29                  44                  42                      42
# ...                ...                 ...                     ...
# 1525                50                  42                      34
# 1526                42                  46                      36
# 1527                50                  32                      34
# 1528                36                  38                      48
# 1529                32                  30                      30
# 1530                44                  42                      24
# 1531                34                  26                      44
# 1532                42                  44                      44
# 1533                46                  44                      28
# 1534                42                  44                      44
# 1535                46                  34                      36
# 1536                50                  28                      44
# 1537                46                  44                      42
# 1538                50                  44                      42
# 1539                46                  34                      40
# 1540                40                  34                      44
# 1541                50                  32                      36
# 1542                46                  40                      36
# 1543                46                  42                      36
# 1544                46                  30                      32
# 1545                36                  28                      32
# 1546                48                  30                      36
# 1547                46                  30                      38
# 1548                28                  24                      46
# 1549                36                  28                      42
# 1550                38                  44                      44
# 1551                40                  44                      34
# 1552                40                  46                      48
# 1553                48                  36                      44
# 1554                42                  40                      30
#
#      Extraversion_Interpretation Agreeableness_Interpretation  \
# ID
# 0                           high                         high
# 1                           high                         high
# 2                           high                         high
# 3                           high                         high
# 4                           high                         high
# 5                           high                         high
# 6                           high                         high
# 7                           high                         high
# 8                           high                         high
# 9                           high                         high
# 10                          high                         high
# 11                          high                         high
# 12                          high                         high
# 13                          high                         high
# 14                          high                         high
# 15                          high                         high
# 16                          high                         high
# 17                          high                         high
# 18                          high                         high
# 19                        medium                         high
# 20                          high                         high
# 21                          high                         high
# 22                          high                         high
# 23                          high                         high
# 24                          high                         high
# 25                        medium                         high
# 26                          high                         high
# 27                          high                         high
# 28                          high                         high
# 29                          high                         high
# ...                          ...                          ...
# 1525                        high                         high
# 1526                        high                         high
# 1527                        high                         high
# 1528                        high                         high
# 1529                        high                         high
# 1530                        high                         high
# 1531                        high                         high
# 1532                        high                         high
# 1533                        high                         high
# 1534                        high                         high
# 1535                        high                         high
# 1536                        high                         high
# 1537                        high                         high
# 1538                        high                         high
# 1539                        high                         high
# 1540                        high                         high
# 1541                        high                         high
# 1542                        high                         high
# 1543                        high                         high
# 1544                        high                         high
# 1545                        high                         high
# 1546                        high                         high
# 1547                        high                         high
# 1548                        high                         high
# 1549                        high                         high
# 1550                        high                         high
# 1551                        high                         high
# 1552                        high                         high
# 1553                        high                         high
# 1554                        high                         high
#
#      Conscientiousness_Interpretation Emotional_Stability_Interpretation  \
# ID
# 0                                high                               high
# 1                                high                               high
# 2                                high                               high
# 3                                high                               high
# 4                                high                               high
# 5                                high                               high
# 6                                high                               high
# 7                                high                               high
# 8                                high                               high
# 9                                high                             medium
# 10                               high                               high
# 11                               high                             medium
# 12                               high                             medium
# 13                               high                               high
# 14                               high                             medium
# 15                               high                               high
# 16                               high                               high
# 17                               high                               high
# 18                               high                                low
# 19                               high                               high
# 20                               high                               high
# 21                               high                               high
# 22                               high                               high
# 23                               high                               high
# 24                               high                               high
# 25                               high                               high
# 26                               high                               high
# 27                               high                                low
# 28                               high                               high
# 29                               high                               high
# ...                               ...                                ...
# 1525                             high                               high
# 1526                             high                               high
# 1527                             high                               high
# 1528                             high                               high
# 1529                             high                               high
# 1530                             high                               high
# 1531                             high                               high
# 1532                             high                               high
# 1533                             high                               high
# 1534                             high                               high
# 1535                             high                               high
# 1536                             high                               high
# 1537                             high                               high
# 1538                             high                               high
# 1539                             high                               high
# 1540                             high                               high
# 1541                             high                               high
# 1542                             high                               high
# 1543                             high                               high
# 1544                             high                               high
# 1545                             high                               high
# 1546                             high                               high
# 1547                             high                               high
# 1548                             high                               high
# 1549                             high                               high
# 1550                             high                               high
# 1551                             high                               high
# 1552                             high                               high
# 1553                             high                               high
# 1554                             high                               high
#
#      Openness_to_experiences_Interpretation Department
# ID
# 0                                      high       Data
# 1                                      high       Data
# 2                                      high       Data
# 3                                      high       Data
# 4                                      high       Data
# 5                                      high       Data
# 6                                      high       Data
# 7                                      high       Data
# 8                                      high       Data
# 9                                      high       Data
# 10                                     high       Data
# 11                                     high       Data
# 12                                     high       Data
# 13                                     high       Data
# 14                                     high       Data
# 15                                     high       Data
# 16                                     high       Data
# 17                                     high       Data
# 18                                     high       Data
# 19                                     high       Data
# 20                                     high       Data
# 21                                     high       Data
# 22                                     high       Data
# 23                                     high       Data
# 24                                     high       Data
# 25                                     high       Data
# 26                                     high       Data
# 27                                     high       Data
# 28                                     high       Data
# 29                                     high    Web Dev
# ...                                     ...        ...
# 1525                                   high    Web dev
# 1526                                   high    Web dev
# 1527                                   high    Web dev
# 1528                                   high    Web dev
# 1529                                   high    Web dev
# 1530                                   high    Web dev
# 1531                                   high    Web dev
# 1532                                   high    Web dev
# 1533                                   high    Web dev
# 1534                                   high    Web dev
# 1535                                   high    Web dev
# 1536                                   high    Web dev
# 1537                                   high    Web dev
# 1538                                   high    Web dev
# 1539                                   high    Web dev
# 1540                                   high    Web dev
# 1541                                   high    Web dev
# 1542                                   high    Web dev
# 1543                                   high    Web dev
# 1544                                   high    Web dev
# 1545                                   high    Web dev
# 1546                                   high    Web dev
# 1547                                   high    Web dev
# 1548                                   high    Web dev
# 1549                                   high    Web dev
# 1550                                   high    Web dev
# 1551                                   high    Web dev
# 1552                                   high    Web dev
# 1553                                   high    Web dev
# 1554                                   high    Web dev
#
# [1555 rows x 61 columns]

# %% [markdown]
# ### 3. Create histograms of personality scores by department. You may need to clean some of the department names.

# %%
cols = ['Extraversion','Agreeableness','Conscientiousness','Emotional Stability','Openness to experiences']
for i in cols:
    combined_data[i].groupby(combined_data['Department']).plot.hist()
    plt.legend()
    plt.show()

# %%
dep = combined_data['Department'].value_counts()
print(dep)
# Out:
# Strategy       449
# Data           329
# Copywriting    326
# Web Dev        170
# Web dev        161
# Design         120
# Name: Department, dtype: int64

# %%
combined_data['Department'] = combined_data['Department'].apply(lambda x: x.replace('Web dev', 'Web Dev'))
dep = combined_data['Department'].value_counts()
print(dep)
# Out:
# Strategy       449
# Web Dev        331
# Data           329
# Copywriting    326
# Design         120
# Name: Department, dtype: int64

# %%
plt.hist(combined_data['Department'].value_counts())
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### 4. Filter the merged data frame so that you get only the ID numbers of applicants who score “low” on emotional stability, conscientiousness or agreeableness. Print the ID numbers and departments of these applicants to the screen, and also assign these applicants the tag “high_risk” in a new column.

# %%
high_risk = combined_data[(combined_data['Emotional_Stability_Interpretation'] == 'low') | (combined_data['Conscientiousness_Interpretation'] == 'low') | (combined_data['Agreeableness_Interpretation'] == 'low')]
high_risk['At_risk'] = 'high_risk'
high_risk = high_risk[['Department','At_risk']]
display(high_risk)
print(len(high_risk))
# Out:
# /home/recruit/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Department    At_risk
# ID
# 18           Data  high_risk
# 27           Data  high_risk
# 526      Strategy  high_risk
# 584      Strategy  high_risk
# 663      Strategy  high_risk
# 960          Data  high_risk
# 1154  Copywriting  high_risk
# 7

# %% [markdown]
# ### 5. Create a new data frame with a count of the number of applicants in the low risk group within each personality subscale and department. Let each department be a separate column, and each personality subscale be a separate row. In other words, the data frame should look something like this:

# %%
# def getList():
#     Strategy = []    
#     Data = []          
#     Copywriting = []    
#     Web Dev = []               
#     Design = []   
#     cols = [personality_data['Extraversion_Interpretation'],
#             personality_data['Agreeableness_Interpretation'],
#             personality_data['Conscientiousness_Interpretation']
#             personality_data['Emotional_Stability_Interpretation'] ,
#             personality_data['Openness_to_experiences_Interpretation'] ]
#     Strategy = []    
#     Data = []          
#     Copywriting = []    
#     Web Dev = []               
#     Design = []
#     for i in something():
def getList(rows):
    dictionary = {}
    count = 0
    data_cols = []
    for i in rows.columns:
        print(rows[i],'some shit')
#         if rows[i] == 'low':
#             data_cols.append(i)
#         print(rows[i])
#     DICT = []
#     for stuff in low.columns:
#         if rows['Department'] == 'Data':
#             #print(rows[stuff])
#             if rows[stuff] == 'low':
#                 DICT.append([rows[stuff],stuff])
    return data_cols

# %%
highs = combined_data[['Extraversion_Interpretation','Agreeableness_Interpretation','Conscientiousness_Interpretation','Emotional_Stability_Interpretation','Openness_to_experiences_Interpretation','Department']]
low = highs[(highs['Extraversion_Interpretation'] == 'low')| (highs['Emotional_Stability_Interpretation'] == 'low') | (highs['Conscientiousness_Interpretation'] == 'low') | (highs['Agreeableness_Interpretation'] == 'low')| (highs['Openness_to_experiences_Interpretation'] == 'low')]
#display(low.head())
# print(type(low))
# low.groupby
low_risk = combined_data[(combined_data['Emotional_Stability_Interpretation'] == 'high') | (combined_data['Conscientiousness_Interpretation'] == 'high') | (combined_data['Agreeableness_Interpretation'] == 'high')]
display(low_risk.head())
print(len(low_risk))
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
# 3                                (5, 5)
# 4                                (5, 3)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 3)
#
#    Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                              (5, 3)
# 1                                              (5, 3)
# 2                                              (5, 5)
# 3                                              (5, 3)
# 4                                              (5, 3)
#
#    Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                              (2, 3)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 5)
#
#    Section 5 of 6 [I am quiet around strangers.]  ... Agreeableness  \
# ID                                                ...
# 0                                         (1, 3)  ...            40
# 1                                         (1, 3)  ...            46
# 2                                         (1, 1)  ...            40
# 3                                         (1, 3)  ...            38
# 4                                         (1, 1)  ...            34
#
#    Conscientiousness Emotional Stability Openness to experiences  \
# ID
# 0                 48                  36                      42
# 1                 46                  40                      42
# 2                 40                  38                      42
# 3                 38                  40                      38
# 4                 46                  38                      36
#
#    Extraversion_Interpretation Agreeableness_Interpretation  \
# ID
# 0                         high                         high
# 1                         high                         high
# 2                         high                         high
# 3                         high                         high
# 4                         high                         high
#
#    Conscientiousness_Interpretation Emotional_Stability_Interpretation  \
# ID
# 0                              high                               high
# 1                              high                               high
# 2                              high                               high
# 3                              high                               high
# 4                              high                               high
#
#    Openness_to_experiences_Interpretation Department
# ID
# 0                                    high       Data
# 1                                    high       Data
# 2                                    high       Data
# 3                                    high       Data
# 4                                    high       Data
#
# [5 rows x 61 columns]
# 1555

# %%
#Data = getList(low)
#print(Data)

# print(low.groupby('Department')['Extraversion_Interpretation'].value_counts() )
# print(low.groupby('Department')['Agreeableness_Interpretation'].value_counts() )
# print(low.groupby('Department')['Conscientiousness_Interpretation'].value_counts() )
# print(low.groupby('Department')['Emotional_Stability_Interpretation'].value_counts() )
# print(low.groupby('Department')['Openness_to_experiences_Interpretation'].value_counts() )

# grouped = low.groupby('Department')
# print(grouped.keys)

# %%
display(low.head())
print(low.Extraversion_Interpretation.value_counts())
# Out:
#    Extraversion_Interpretation Agreeableness_Interpretation  \
# ID
# 18                        high                         high
# 27                        high                         high
# 74                         low                         high
# 85                         low                         high
# 91                         low                         high
#
#    Conscientiousness_Interpretation Emotional_Stability_Interpretation  \
# ID
# 18                             high                                low
# 27                             high                                low
# 74                             high                               high
# 85                             high                             medium
# 91                             high                               high
#
#    Openness_to_experiences_Interpretation Department
# ID
# 18                                   high       Data
# 27                                   high       Data
# 74                                   high    Web Dev
# 85                                   high    Web Dev
# 91                                   high    Web Dev
# low       41
# high       5
# medium     1
# Name: Extraversion_Interpretation, dtype: int64

# %%
def attempt(we):
    countExtraversion = 0
    countAgreeableness = 0
    countConscientiousness = 0
    countEmotional_Stability = 0
    countOpenness_to_experiences = 0
    print(we)
    #we are itterating through the first array
    for i in we:
        #print(i)
        if i[0] == 'low':
            #print(i[0])
            countExtraversion += 1
        if i[1] == 'low':
            print(i[0])
            countAgreeableness += 1
        if i[2] == 'low':
            print(i[0])
            countConscientiousness += 1
        if i[3] == 'low':
            print(i[0])
            countEmotional_Stability += 1
        if i[4] == 'low':
            print(i[0])
            countOpenness_to_experiences += 1
        #countExtraversion+= 1
        for j in i:
            #print(j)
            pass
        #print('we',i)
    return [countExtraversion , countAgreeableness, countConscientiousness,countEmotional_Stability,countOpenness_to_experiences]

# %%
def attemptRight(we):
    countExtraversion = 0
    countAgreeableness = 0
    countConscientiousness = 0
    countEmotional_Stability = 0
    countOpenness_to_experiences = 0
    print(we)
    #we are itterating through the first array
    for i in we:
        print(i)
        if i[0] == 'high' or i[0] == 'medium':
            #print(i[0])
            countExtraversion += 1
        if i[1] == 'high' or i[0] == 'medium':
            print(i[0])
            countAgreeableness += 1
        if i[2] == 'high' or i[0] == 'medium':
            print(i[0])
            countConscientiousness += 1
        if i[3] == 'high' or i[0] == 'medium':
            print(i[0])
            countEmotional_Stability += 1
        if i[4] == 'high' or i[0] == 'medium':
            print(i[0])
            countOpenness_to_experiences += 1
        #countExtraversion+= 1
        for j in i:
            #print(j)
            pass
        #print('we',i)
    return [countExtraversion , countAgreeableness, countConscientiousness,countEmotional_Stability,countOpenness_to_experiences]

# %%
#low.groupby('Department').filter(lambda group: attempt(group.values))
#print(low.head())
a = low.groupby('Department').apply(lambda group: attempt(group.values))
#print(a)
#print(type(a))
# ab = a.to_frame()
# display(ab)
# print(ab.columns)
# ab


# low.groupby(['Department'])['ID'].count()
# groupedd = low.groupby('Department')
# groupedd.filter(lambda x: x['Agreeableness_Interpretation'].mean() > 3.)
# Out:
# [['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'low' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'medium' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'high' 'high' 'Copywriting']]
# low
# [['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'low' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'medium' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['low' 'high' 'high' 'high' 'high' 'Copywriting']]
# low
# [['high' 'high' 'high' 'low' 'high' 'Data']
#  ['high' 'high' 'high' 'low' 'high' 'Data']
#  ['low' 'high' 'high' 'high' 'high' 'Data']
#  ['low' 'high' 'high' 'high' 'high' 'Data']
#  ['high' 'high' 'low' 'high' 'high' 'Data']
#  ['low' 'high' 'high' 'high' 'high' 'Data']
#  ['low' 'high' 'high' 'medium' 'high' 'Data']
#  ['low' 'high' 'high' 'high' 'high' 'Data']]
# high
# high
# high
# [['low' 'high' 'high' 'high' 'high' 'Design']]
# [['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['high' 'high' 'low' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['high' 'high' 'low' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['medium' 'high' 'medium' 'low' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'medium' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']
#  ['low' 'high' 'high' 'high' 'high' 'Strategy']]
# high
# high
# medium
# [['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'medium' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'high' 'high' 'Web Dev']
#  ['low' 'high' 'high' 'medium' 'high' 'Web Dev']]

# %%
#t')['Extraversion_Interpretation'].value_counts() )
# print(low.groupby('Department')['Agreeableness_Interpretation'].value_counts() )
# print(low.groupby('Department')['Conscientiousness_Interpretation'].value_counts() )
# print(low.groupby('Department')['Emotional_Stability_Interpretation'].value_counts() )
# print(low.groupby('Department')['Openness_to_experiences_Interpretation'].value_counts() )
b = combined_data[['Extraversion_Interpretation','Agreeableness_Interpretation','Conscientiousness_Interpretation','Emotional_Stability_Interpretation','Openness_to_experiences_Interpretation','Department']]
#display(b)
c = b.groupby('Department').apply(lambda group: attemptRight(group.values))
print(c)
print(type(c))
ab = c.to_frame()
display(ab)
print(ab.columns)
ab
# Out:
# [['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ...
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']]
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'medium' 'high' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'low' 'high' 'Copywriting']
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'medium' 'high' 'Copywriting']
# low
# low
# low
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'medium' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'medium' 'high' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# [['low' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ...
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']
#  ['high' 'high' 'high' 'high' 'high' 'Copywriting']]
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'medium' 'high' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'low' 'high' 'Copywriting']
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'medium' 'high' 'Copywriting']
# low
# low
# low
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'medium' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'medium' 'high' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Copywriting']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Copywriting']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Copywriting']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Copywriting']
# high
# high
# high
# high
# [['high' 'high' 'high' 'high' 'high' 'Data']
#  ['high' 'high' 'high' 'high' 'high' 'Data']
#  ['high' 'high' 'high' 'high' 'high' 'Data']
#  ...
#  ['medium' 'high' 'high' 'high' 'high' 'Data']
#  ['high' 'high' 'high' 'high' 'high' 'Data']
#  ['medium' 'high' 'high' 'high' 'high' 'Data']]
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Data']
# high
# ...
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'medium' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'medium' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['low' 'high' 'high' 'medium' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'medium' 'high' 'Web dev']
#  ['high' 'high' 'high' 'medium' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'medium' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['medium' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'medium' 'medium' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']
#  ['high' 'high' 'high' 'high' 'high' 'Web dev']]
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Web dev']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Web dev']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Web dev']
# low
# low
# low
# low
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Web dev']
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['low' 'high' 'high' 'high' 'high' 'Web dev']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Web dev']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['low' 'high' 'high' 'high' 'high' 'Web dev']
# low
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'medium' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Web dev']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['low' 'high' 'high' 'medium' 'high' 'Web dev']
# low
# low
# low
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Web dev']
# high
# high
# high
# ['high' 'high' 'high' 'medium' 'high' 'Web dev']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'medium' 'high' 'high' 'Web dev']
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['medium' 'high' 'high' 'high' 'high' 'Web dev']
# medium
# medium
# medium
# medium
# ['high' 'high' 'high' 'medium' 'medium' 'Web dev']
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# ['high' 'high' 'high' 'high' 'high' 'Web dev']
# high
# high
# high
# high
# Department
# Copywriting    [320, 325, 324, 317, 326]
# Data           [324, 329, 328, 318, 329]
# Design         [119, 120, 120, 117, 120]
# Strategy       [434, 448, 439, 444, 448]
# Web Dev        [162, 170, 167, 169, 169]
# Web dev        [155, 161, 160, 154, 160]
# dtype: object
# <class 'pandas.core.series.Series'>
#                                      0
# Department
# Copywriting  [320, 325, 324, 317, 326]
# Data         [324, 329, 328, 318, 329]
# Design       [119, 120, 120, 117, 120]
# Strategy     [434, 448, 439, 444, 448]
# Web Dev      [162, 170, 167, 169, 169]
# Web dev      [155, 161, 160, 154, 160]
# RangeIndex(start=0, stop=1, step=1)
#                                      0
# Department
# Copywriting  [320, 325, 324, 317, 326]
# Data         [324, 329, 328, 318, 329]
# Design       [119, 120, 120, 117, 120]
# Strategy     [434, 448, 439, 444, 448]
# Web Dev      [162, 170, 167, 169, 169]
# Web dev      [155, 161, 160, 154, 160]

# %%
def assigningResults(row,Category_Num):
    count = 0
    
    for column in ab.columns:
        tuplee = row[column]
        if type(tuplee) == list:
            return tuplee[Category_Num]
        else:
            pass
    return tuplee[Category_Num]

# %%
ab['Extraversion'] = ab.apply(lambda row : assigningResults(row,0), axis = 1)
ab['Agreeableness'] = ab.apply(lambda row : assigningResults(row,1), axis = 1)
ab['Conscientiousness'] = ab.apply(lambda row : assigningResults(row,2), axis = 1)
ab['Emotional Stability'] = ab.apply(lambda row : assigningResults(row,3), axis = 1)
ab['Openness to experiences'] = ab.apply(lambda row : assigningResults(row,4), axis = 1)

# %%
ab = ab.drop(columns=[0])

# %%
ab
# Out:
#              Extraversion  Agreeableness  Conscientiousness  \
# Department
# Copywriting           320            325                324
# Data                  324            329                328
# Design                119            120                120
# Strategy              434            448                439
# Web Dev               162            170                167
# Web dev               155            161                160
#
#              Emotional Stability  Openness to experiences
# Department
# Copywriting                  317                      326
# Data                         318                      329
# Design                       117                      120
# Strategy                     444                      448
# Web Dev                      169                      169
# Web dev                      154                      160
