# %% [markdown]
# ### 1. Read in the dataset personality_scores.csv in this repo. Examine the data frame for duplicates (based on ID), and drop any duplicates that exist. Assert that the new data frame is the length of the unique entries of the original data frame.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
personality_data = pd.read_csv('CSV/personality_scores.csv',delimiter=';')
personality_data = personality_data.drop_duplicates(subset='ID')
personality_data =personality_data.set_index('ID')
personality_data = personality_data.dropna(axis=1)
#print(personality_data.isna())
display(personality_data.head())

#assert len(personality_data) = len(personality_data['continent'].unique())
#print(personality_data.columns)
#print(personality_data.columns)
# count = 0
# for i in personality_data.columns:
#     print(count,i)
#     count += 1
#(catergory,score)
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
# 3                                (5, 5)
# 4                                (5, 3)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 3)
#
#    Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                              (5, 3)
# 1                                              (5, 3)
# 2                                              (5, 5)
# 3                                              (5, 3)
# 4                                              (5, 3)
#
#    Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                              (2, 3)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 5)
#
#    Section 5 of 6 [I am quiet around strangers.]  ...  \
# ID                                                ...
# 0                                         (1, 3)  ...
# 1                                         (1, 3)  ...
# 2                                         (1, 1)  ...
# 3                                         (1, 3)  ...
# 4                                         (1, 1)  ...
#
#    Section 5 of 6 [I often forget to put things back in their proper place]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 5)
# 3                                              (3, 1)
# 4                                              (3, 5)
#
#    Section 5 of 6 [I pay attention to details.]  \
# ID
# 0                                        (3, 5)
# 1                                        (3, 1)
# 2                                        (3, 5)
# 3                                        (3, 5)
# 4                                        (3, 5)
#
#    Section 5 of 6 [I seldom feel blue (down).]  \
# ID
# 0                                       (4, 3)
# 1                                       (4, 1)
# 2                                       (4, 1)
# 3                                       (4, 1)
# 4                                       (4, 5)
#
#    Section 5 of 6 [I spend time reflecting on things.]  \
# ID
# 0                                              (5, 5)
# 1                                              (5, 5)
# 2                                              (5, 3)
# 3                                              (5, 5)
# 4                                              (5, 5)
#
#    Section 5 of 6 [I start conversations.]  \
# ID
# 0                                   (1, 3)
# 1                                   (1, 5)
# 2                                   (1, 3)
# 3                                   (1, 5)
# 4                                   (1, 3)
#
#    Section 5 of 6 [I sympathize with others' feelings.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 5)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I take time out for others.]  \
# ID
# 0                                        (2, 5)
# 1                                        (2, 5)
# 2                                        (2, 5)
# 3                                        (2, 5)
# 4                                        (2, 5)
#
#    Section 5 of 6 [I talk to a lot of different people at parties.]  \
# ID
# 0                                              (1, 3)
# 1                                              (1, 5)
# 2                                              (1, 3)
# 3                                              (1, 5)
# 4                                              (1, 3)
#
#    Section 5 of 6 [I use difficult words.]  \
# ID
# 0                                   (5, 1)
# 1                                   (5, 3)
# 2                                   (5, 1)
# 3                                   (5, 1)
# 4                                   (5, 1)
#
#    Section 5 of 6 [I worry about things.]
# ID
# 0                                  (4, 3)
# 1                                  (4, 3)
# 2                                  (4, 3)
# 3                                  (4, 1)
# 4                                  (4, 3)
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Write functions that will (1) convert the answer on each of the personality test questions to a number, as set out in scoring, and (2) calculate total scores for each of the subscales (conscientiousness, emotional stability, openness to new experience, agreeableness, extraversion). As you are doing this, first create unit tests that will test that the functions work as they should.

# %%
#(1) Extraversion, 
# (2) Agreeableness, 
# (3) Conscientiousness, 
# (4) Emotional Stability/Neuroticism,  
# (5)Intellect/Imagination / openness to experiences)
def assigning(row,Category_Num):
    count = 0
    asd = 0
    for column in personality_data.columns:
        if column != None:
            tuplee = row[column]
            catergory = tuplee[1]
            result = int(tuplee[4])
#             if catergory == Category_Num:
#                 count += result
#             else: 
#                 pass
        asd += 1
        print(result)
    return count

# %%
# personality_data['Extraversion'] = personality_data.apply(lambda row : assigning(row,'1'), axis = 1)
personality_data['Agreeableness'] = personality_data.apply(lambda row : assigning(row,'2'), axis = 1)
# personality_data['Conscientiousness'] = personality_data.apply(lambda row : assigning(row,'3'), axis = 1)
# personality_data['Emotional Stability'] = personality_data.apply(lambda row : assigning(row,'4'), axis = 1)
# personality_data['Openness to experiences'] = personality_data.apply(lambda row : assigning(row,'5'), axis = 1)
# Out:
# 5
# 5
# 5
# 5
# 3
# 3
# 3
# 5
# 5
# 3
# 3
# 3
# 5
# 5
# 3
# 1
# 3
# 5
# 1
# 3
# 5
# 5
# 3
# 3
# 3
# 5
# 5
# 3
# 5
# 5
# 5
# 3
# 5
# 3
# 5
# 5
# 3
# 5
# 5
# 3
# 5
# 5
# 3
# 5
# 3
# 5
# 5
# 3
# 1
# 3
# 5
# 5
# 5
# 5
# 3
# 3
# 3
# 5
# 5
# 3
# 3
# 3
# 5
# 5
# 3
# 1
# 3
# 5
# 1
# 3
# 5
# 5
# 3
# 3
# 3
# 5
# 5
# 3
# 5
# 5
# 5
# 3
# 5
# 3
# 5
# 5
# 3
# 5
# 5
# 3
# 5
# 5
# 3
# 5
# 3
# 5
# 5
# 3
# 1
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d350d113821c> in <module>
#       1 # personality_data['Extraversion'] = personality_data.apply(lambda row : assigning(row,'1'), axis = 1)
# ----> 2 personality_data['Agreeableness'] = personality_data.apply(lambda row : assigning(row,'2'), axis = 1)
#       3 # personality_data['Conscientiousness'] = personality_data.apply(lambda row : assigning(row,'3'), axis = 1)
#       4 # personality_data['Emotional Stability'] = personality_data.apply(lambda row : assigning(row,'4'), axis = 1)
#       5 # personality_data['Openness to experiences'] = personality_data.apply(lambda row : assigning(row,'5'), axis = 1)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-20-d350d113821c> in <lambda>(row)
#       1 # personality_data['Extraversion'] = personality_data.apply(lambda row : assigning(row,'1'), axis = 1)
# ----> 2 personality_data['Agreeableness'] = personality_data.apply(lambda row : assigning(row,'2'), axis = 1)
#       3 # personality_data['Conscientiousness'] = personality_data.apply(lambda row : assigning(row,'3'), axis = 1)
#       4 # personality_data['Emotional Stability'] = personality_data.apply(lambda row : assigning(row,'4'), axis = 1)
#       5 # personality_data['Openness to experiences'] = personality_data.apply(lambda row : assigning(row,'5'), axis = 1)
#
# <ipython-input-19-f0d0f62e3434> in assigning(row, Category_Num)
#       9         if column != None:
#      10             tuplee = row[column]
# ---> 11             catergory = tuplee[1]
#      12             result = int(tuplee[4])
#      13 #             if catergory == Category_Num:
#
# TypeError: ("'int' object is not subscriptable", 'occurred at index 0')

# %%
personality_data.head()
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# 1                                (5, 5)
# 2                                (5, 5)
# 3                                (5, 5)
# 4                                (5, 3)
#
#    Section 5 of 6 [I am interested in people.]  \
# ID
# 0                                       (2, 3)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 3)
#
#    Section 5 of 6 [I am not interested in abstract ideas.]  \
# ID
# 0                                              (5, 3)
# 1                                              (5, 3)
# 2                                              (5, 5)
# 3                                              (5, 3)
# 4                                              (5, 3)
#
#    Section 5 of 6 [I am not interested in other people's problems.]  \
# ID
# 0                                              (2, 3)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am not really interested in others.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 3)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I am quick to understand things.]  \
# ID
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 5)
#
#    Section 5 of 6 [I am quiet around strangers.]  ...  \
# ID                                                ...
# 0                                         (1, 3)  ...
# 1                                         (1, 3)  ...
# 2                                         (1, 1)  ...
# 3                                         (1, 3)  ...
# 4                                         (1, 1)  ...
#
#    Section 5 of 6 [I pay attention to details.]  \
# ID
# 0                                        (3, 5)
# 1                                        (3, 1)
# 2                                        (3, 5)
# 3                                        (3, 5)
# 4                                        (3, 5)
#
#    Section 5 of 6 [I seldom feel blue (down).]  \
# ID
# 0                                       (4, 3)
# 1                                       (4, 1)
# 2                                       (4, 1)
# 3                                       (4, 1)
# 4                                       (4, 5)
#
#    Section 5 of 6 [I spend time reflecting on things.]  \
# ID
# 0                                              (5, 5)
# 1                                              (5, 5)
# 2                                              (5, 3)
# 3                                              (5, 5)
# 4                                              (5, 5)
#
#    Section 5 of 6 [I start conversations.]  \
# ID
# 0                                   (1, 3)
# 1                                   (1, 5)
# 2                                   (1, 3)
# 3                                   (1, 5)
# 4                                   (1, 3)
#
#    Section 5 of 6 [I sympathize with others' feelings.]  \
# ID
# 0                                              (2, 5)
# 1                                              (2, 5)
# 2                                              (2, 5)
# 3                                              (2, 5)
# 4                                              (2, 3)
#
#    Section 5 of 6 [I take time out for others.]  \
# ID
# 0                                        (2, 5)
# 1                                        (2, 5)
# 2                                        (2, 5)
# 3                                        (2, 5)
# 4                                        (2, 5)
#
#    Section 5 of 6 [I talk to a lot of different people at parties.]  \
# ID
# 0                                              (1, 3)
# 1                                              (1, 5)
# 2                                              (1, 3)
# 3                                              (1, 5)
# 4                                              (1, 3)
#
#    Section 5 of 6 [I use difficult words.]  \
# ID
# 0                                   (5, 1)
# 1                                   (5, 3)
# 2                                   (5, 1)
# 3                                   (5, 1)
# 4                                   (5, 1)
#
#    Section 5 of 6 [I worry about things.] Extraversion
# ID
# 0                                  (4, 3)           30
# 1                                  (4, 3)           42
# 2                                  (4, 3)           28
# 3                                  (4, 1)           30
# 4                                  (4, 3)           28
#
# [5 rows x 51 columns]

# %% [markdown]
# ### 1 . Create a function/functions that takes in subscale total, and for each subscale, creates a new column called “{subscale_name}_interpretation” (e.g., conscientiousness_interpretation) and applies the labels “low”, “medium”, or “high” according to a person’s score on that subscale. Cut-off scores corresponding to the low, medium and high groups can be found in scoring.md. Again, write a unit test before creating this function that tests whether the generate_score_interpretation function works.

# %% [markdown]
# ### 2 . Read in the data in departments.csv and merge this data frame with the personality score data frame, keeping all applicants within the department data frame. Assert that the newly created merged data frame has the same amount of rows as the department data frame, and the expected number of columns.

# %% [markdown]
# ### 3. Create histograms of personality scores by department. You may need to clean some of the department names.

# %% [markdown]
# ### 5. Filter the merged data frame so that you get only the ID numbers of applicants who score “low” on emotional stability, conscientiousness or agreeableness. Print the ID numbers and departments of these applicants to the screen, and also assign these applicants the tag “high_risk” in a new column.

# %% [markdown]
# ### 6 Create a new data frame with a count of the number of applicants in the low risk group within each personality subscale and department. Let each department be a separate column, and each personality subscale be a separate row. In other words, the data frame should look something like this:
